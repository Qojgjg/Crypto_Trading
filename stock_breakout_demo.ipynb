# %% [markdown]
# <a href="https://colab.research.google.com/github/yongghongg/stock-screener/blob/main/stock_breakout_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# !pip install mplfinance
import requests
from bs4 import BeautifulSoup
import pandas as pd
import yfinance as yf
import numpy as np
import math
from mplfinance.original_flavor import candlestick_ohlc
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt

from binance.client import Client
import pandas as pd
import numpy as np
import yfinance
from mpl_finance import candlestick_ohlc
import matplotlib.dates as mpl_dates
import matplotlib.pyplot as plt
import pyarrow.parquet as pq
import pyarrow as pa
# Out:
# Requirement already satisfied: yfinance in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (0.1.70)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from yfinance) (4.9.0)
# Requirement already satisfied: requests>=2.26 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from yfinance) (1.22.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from requests>=2.26->yfinance) (2022.5.18.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: mplfinance in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (0.12.9b1)
# Requirement already satisfied: pandas in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from mplfinance) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from mplfinance) (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from matplotlib->mplfinance) (4.32.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from matplotlib->mplfinance) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from matplotlib->mplfinance) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from matplotlib->mplfinance) (1.22.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from matplotlib->mplfinance) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from matplotlib->mplfinance) (9.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from matplotlib->mplfinance) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dung.duong\anaconda3\envs\dungduong\lib\site-packages (from pandas->mplfinance) (2022.1)
# C:\Users\dung.duong\Anaconda3\envs\dungduong\lib\site-packages\mpl_finance.py:16: DeprecationWarning:
#
#   =================================================================
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
#   =================================================================
#
#   __warnings.warn('\n\n  ================================================================='+

# %%
api_key = "zzjxplMhUgyz4Jp1ju8TbAp4mlAAH1HdXnwuNWaHboge5HR6yOOPFKD3x68TR5Iv"
api_secret = "RmBL4M2AJSnzY5Dk4nec0dD0tgD9Eox8vwkqKIyWYkQus7oPhm5a7ilMz2vgMiyP"
client = Client(api_key, api_secret)


start_date = "3 day ago UTC"
period = Client.KLINE_INTERVAL_15MINUTE
code = "OPUSDT"
# code = "LUNCUSDT"
code = "LINAUSDT"
code = "LUNCUSDT"

data = client.get_historical_klines(code, period, start_date)
data = [x[:6] for x in data]
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# Input In [136], in <cell line: 13>()
#      10 code = "LINAUSDT"
#      11 code = "LUNCUSDT"
# ---> 13 data = client.get_historical_klines(code, period, start_date)
#      14 data = [x[:6] for x in data]
#
# File ~\Anaconda3\envs\dungduong\lib\site-packages\binance\client.py:934, in Client.get_historical_klines(self, symbol, interval, start_str, end_str, limit, klines_type)
#     914 def get_historical_klines(self, symbol, interval, start_str=None, end_str=None, limit=1000,
#     915                           klines_type: HistoricalKlinesType = HistoricalKlinesType.SPOT):
#     916     """Get Historical Klines from Binance
#     917
#     918     :param symbol: Name of symbol pair e.g BNBBTC
#    (...)
#     932
#     933     """
# --> 934     return self._historical_klines(
#     935         symbol, interval, start_str=start_str, end_str=end_str, limit=limit, klines_type=klines_type
#     936     )
#
# File ~\Anaconda3\envs\dungduong\lib\site-packages\binance\client.py:973, in Client._historical_klines(self, symbol, interval, start_str, end_str, limit, klines_type)
#     971 # establish first available start timestamp
#     972 if start_ts is not None:
# --> 973     first_valid_ts = self._get_earliest_valid_timestamp(symbol, interval, klines_type)
#     974     start_ts = max(start_ts, first_valid_ts)
#     976 # if an end time was passed convert it
#
# File ~\Anaconda3\envs\dungduong\lib\site-packages\binance\client.py:904, in Client._get_earliest_valid_timestamp(self, symbol, interval, klines_type)
#     891 def _get_earliest_valid_timestamp(self, symbol, interval, klines_type: HistoricalKlinesType = HistoricalKlinesType.SPOT):
#     892     """Get earliest valid open timestamp from Binance
#     893
#     894     :param symbol: Name of symbol pair e.g BNBBTC
#    (...)
#     902
#     903     """
# --> 904     kline = self._klines(
#     905         klines_type=klines_type,
#     906         symbol=symbol,
#     907         interval=interval,
#     908         limit=1,
#     909         startTime=0,
#     910         endTime=int(time.time() * 1000)
#     911     )
#     912     return kline[0][0]
#
# File ~\Anaconda3\envs\dungduong\lib\site-packages\binance\client.py:883, in Client._klines(self, klines_type, **params)
#     880     del params['endTime']
#     882 if HistoricalKlinesType.SPOT == klines_type:
# --> 883     return self.get_klines(**params)
#     884 elif HistoricalKlinesType.FUTURES == klines_type:
#     885     return self.futures_klines(**params)
#
# File ~\Anaconda3\envs\dungduong\lib\site-packages\binance\client.py:868, in Client.get_klines(self, **params)
#     828 def get_klines(self, **params) -> Dict:
#     829     """Kline/candlestick bars for a symbol. Klines are uniquely identified by their open time.
#     830
#     831     https://binance-docs.github.io/apidocs/spot/en/#kline-candlestick-data
#    (...)
#     866
#     867     """
# --> 868     return self._get('klines', data=params, version=self.PRIVATE_API_VERSION)
#
# File ~\Anaconda3\envs\dungduong\lib\site-packages\binance\client.py:371, in Client._get(self, path, signed, version, **kwargs)
#     370 def _get(self, path, signed=False, version=BaseClient.PUBLIC_API_VERSION, **kwargs):
# --> 371     return self._request_api('get', path, signed, version, **kwargs)
#
# File ~\Anaconda3\envs\dungduong\lib\site-packages\binance\client.py:334, in Client._request_api(self, method, path, signed, version, **kwargs)
#     330 def _request_api(
#     331     self, method, path: str, signed: bool = False, version=BaseClient.PUBLIC_API_VERSION, **kwargs
#     332 ):
#     333     uri = self._create_api_uri(path, signed, version)
# --> 334     return self._request(method, uri, signed, **kwargs)
#
# File ~\Anaconda3\envs\dungduong\lib\site-packages\binance\client.py:315, in Client._request(self, method, uri, signed, force_params, **kwargs)
#     312 kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
#     314 self.response = getattr(self.session, method)(uri, **kwargs)
# --> 315 return self._handle_response(self.response)
#
# File ~\Anaconda3\envs\dungduong\lib\site-packages\binance\client.py:324, in Client._handle_response(response)
#     319 """Internal helper for handling API responses from the Binance server.
#     320 Raises the appropriate exceptions when necessary; otherwise, returns the
#     321 response.
#     322 """
#     323 if not (200 <= response.status_code < 300):
# --> 324     raise BinanceAPIException(response, response.status_code, response.text)
#     325 try:
#     326     return response.json()
#
# BinanceAPIException: APIError(code=-1121): Invalid symbol.

# %%
df = pd.DataFrame(data, columns=['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])
df.Date = pd.to_datetime(df.Date, unit='ms')
df['DateTime'] = df.Date.copy()
df.set_index('Date', inplace=True)
df = df.rename(columns = {'DateTime':'Date'})
df = df[['Date','Open', 'High', 'Low', 'Close','Volume']]
df['Date'] = [mpl_dates.date2num(x) for x in df.index]
df[['Open', 'High', 'Low', 'Close', 'Volume']] = df[['Open', 'High', 'Low', 'Close', 'Volume']].astype(float)
df = df[['Date','Open', 'High', 'Low', 'Close', 'Volume']]

# %%
df.shape
# Out:
# (288, 6)

# %%
# method 1: fractal candlestick pattern

def get_stock_price(symbol):
  df = yf.download(symbol, start='2021-02-01', threads= False)
  df['Date'] = pd.to_datetime(df.index)
  df['Date'] = df['Date'].apply(mpl_dates.date2num)
  df = df.loc[:,['Date', 'Open', 'High', 'Low', 'Close']]
  return df

def is_support(df,i):
  cond1 = df['Low'][i] < df['Low'][i-1] 
  cond2 = df['Low'][i] < df['Low'][i+1] 
  cond3 = df['Low'][i+1] < df['Low'][i+2] 
  cond4 = df['Low'][i-1] < df['Low'][i-2]
  return (cond1 and cond2 and cond3 and cond4)

def is_resistance(df,i):
  cond1 = df['High'][i] > df['High'][i-1] 
  cond2 = df['High'][i] > df['High'][i+1] 
  cond3 = df['High'][i+1] > df['High'][i+2] 
  cond4 = df['High'][i-1] > df['High'][i-2]
  return (cond1 and cond2 and cond3 and cond4)

def is_far_from_level(value, levels, df):
    ave =  np.mean(df['High'] - df['Low'])
    return np.sum([abs(value - level) < ave for _, level in levels]) == 0

def plot_all(levels, df):
    fig, ax = plt.subplots(figsize=(16, 9), dpi=300)
    candlestick_ohlc(ax,df.values,width=0.6, colorup='green', colordown='red', alpha=0.8)
    date_format = mpl_dates.DateFormatter('%d %b %Y')
    ax.xaxis.set_major_formatter(date_format)
    for level in levels:
        plt.hlines(level[1], xmin=df['Date'][level[0]], xmax=max(df['Date']), colors='blue', linestyle='--')
    fig.show()

# df = get_stock_price("COO")
levels = []
for i in range(2,len(df)-2):
  if is_support(df,i):
    l = df['Low'][i]
    if is_far_from_level(l, levels, df):
      levels.append((i,l))
  elif is_resistance(df,i):
    l = df['High'][i]
    if is_far_from_level(l, levels, df):
      levels.append((i,l))

plot_all(levels, df)
# Out:
# C:\Users\dung.duong\AppData\Local\Temp\ipykernel_30240\1387277053.py:35: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df = pd.DataFrame(data, columns=['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])
df.Date = pd.to_datetime(df.Date, unit='ms')
df['DateTime'] = df.Date.copy()
df.set_index('Date', inplace=True)
df = df.rename(columns = {'DateTime':'Date'})
df = df[['Date','Open', 'High', 'Low', 'Close','Volume']]
df['Date'] = [mpl_dates.date2num(x) for x in df.index]
df[['Open', 'High', 'Low', 'Close', 'Volume']] = df[['Open', 'High', 'Low', 'Close', 'Volume']].astype(float)
df = df[['Date','Open', 'High', 'Low', 'Close', 'Volume']]


pivots = []
max_list = []
min_list = []
for i in range(5, len(df)-5):
    high_range = df['High'][i-5:i+4]
    current_max = high_range.max()

    if current_max not in max_list:
        max_list = []
    max_list.append(current_max)
    if len(max_list) == 5 and is_far_from_level(current_max, pivots, df):
        pivots.append((high_range.idxmax(), current_max))
    
    low_range = df['Low'][i-5:i+5]
    current_min = low_range.min()
    if current_min not in min_list:
        min_list = []
    min_list.append(current_min)
    if len(min_list) == 5 and is_far_from_level(current_min, pivots, df):
        pivots.append((low_range.idxmin(), current_min))

plot_all(pivots, df)
# Out:
# C:\Users\dung.duong\AppData\Local\Temp\ipykernel_30240\1387277053.py:35: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# screening
def has_breakout(levels, previous, last):
  for _, level in levels:
    cond1 = (previous['Open'] < level) # to make sure previous candle is below the level
    cond2 = (last['Open'] > level) and (last['Low'] > level)
  return (cond1 and cond2)

def detect_level_method_1(df):
  levels = []
  for i in range(2,df.shape[0]-2):
    if is_support(df,i):
      l = df['Low'][i]
      if is_far_from_level(l, levels, df):
        levels.append((i,l))
    elif is_resistance(df,i):
      l = df['High'][i]
      if is_far_from_level(l, levels, df):
        levels.append((i,l))
  return levels

def detect_level_method_2(df):
  levels = []
  max_list = []
  min_list = []
  for i in range(5, len(df)-5):
      high_range = df['High'][i-5:i+4]
      current_max = high_range.max()

      if current_max not in max_list:
          max_list = []
      max_list.append(current_max)
      if len(max_list) == 5 and is_far_from_level(current_max, levels, df):
          levels.append((high_range.idxmax(), current_max))
      
      low_range = df['Low'][i-5:i+5]
      current_min = low_range.min()
      if current_min not in min_list:
          min_list = []
      min_list.append(current_min)
      if len(min_list) == 5 and is_far_from_level(current_min, levels, df):
          levels.append((low_range.idxmin(), current_min))
  return levels

# lists to store the screened results
# screened_list_1 = [] 
# screened_list_2 = []

# get the full stock list of S&P 500 
# payload=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
# stock_list = payload[0]['Symbol'].values.tolist()

# for symbol in stock_list:
#   try: 
#     df = get_stock_price(symbol)
    
#     levels_1 = detect_level_method_1(df)
#     if (has_breakout(levels_1[-5:], df.iloc[-2], df.iloc[-1])):
#       screened_list_1.append(symbol)

#     levels_2 = detect_level_method_2(df)
#     if (has_breakout(levels_2[-5:], df.iloc[-2], df.iloc[-1])):
#       screened_list_2.append(symbol)

#   except Exception as e:
#     print(e)

# %%
# screened_list_1

# %%
# screened_list_2
